# %% [raw]
# Esc + M - Markdown
# Esc + R - Raw
# Esc + Y - Code
# Esc + 1 - Heading 1
# Esc + 2 - Heading 2
# Esc + 3 - Heading 3

# %% [markdown]
# ### Word2Vec  (Words are converted to Vectors)

# %%
# !pip3 install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import nltk

# %%
# !pip3 install -U scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 7.1 MB 6.5 MB/s eta 0:00:01
# ...

# %%
import gensim
import nltk
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import sklearn

# %%
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /home/kumarmai/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /home/kumarmai/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /home/kumarmai/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/kumarmai/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /home/kumarmai/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /home/kumarmai/nltk_data...
# ...

# %%
from gensim.models import Word2Vec
from nltk.corpus import gutenberg

# %%
# !pip3 list
# Out:
# Package              Version
# -------------------- -------------------
# absl-py              0.9.0
# asn1crypto           0.24.0
# astor                0.8.1
# attrs                19.3.0
# Automat              0.6.0
# backcall             0.1.0
# bleach               3.1.4
# blinker              1.4
# blis                 0.4.1
# bokeh                2.0.2
# boto                 2.49.0
# boto3                1.13.0
# botocore             1.16.0
# cachetools           4.1.0
# catalogue            1.0.0
# certifi              2020.4.5.1
# chardet              3.0.4
# click                6.7
# cloud-init           19.4
# colorama             0.3.7
# command-not-found    0.3
# configobj            5.0.6
# constantly           15.1.0
# cryptography         2.1.4
# cycler               0.10.0
# cymem                2.0.3
# decorator            4.4.2
# defusedxml           0.6.0
# distro-info          0.18ubuntu0.18.04.1
# docutils             0.15.2
# en-core-web-sm       2.2.5
# ...

# %%
# !pip3 install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 24.2 MB 191 kB/s  eta 0:00:01     |████████████████████████████▏   | 21.3 MB 20.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 103 kB 17.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.4 MB 10.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 128 kB 17.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 6.2 MB 18.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 69 kB 3.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 547 kB 13.9 MB/s eta 0:00:01
# ...
#   Created wheel for smart-open: filename=smart_open-2.0.0-py3-none-any.whl size=101341 sha256=4f429a1ed2da484bde89ba56a2ca320053fe3684901af928651c22c80b70ebb2
#   Stored in directory: /home/kumarmai/.cache/pip/wheels/16/64/85/f3205b74e01a98fb81e081c0d61c2ecd04e4645a986db3726e
# Successfully built smart-open
# ...

# %%
Word2Vec()

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
stream = gutenberg.words("bible-kjv.txt")

# %%
all_text = []
for block in stream:
    all_text.extend(block)
    break

# %%
len(all_text)
# Out:
# 1

# %%
len(set(all_text))
# Out:
# 1

# %%
senteces = [["OnePlus has confirmed that the OnePlus 5 and OnePlus 5T will get the Android Q update."], 
            ["The company has announced this on its forums, but has cautioned that users should not expect a launch timeline."],
            ["The company faced a lot of flak for committing to the Android Pie rollout for the OnePlus 3 and OnePlus 3T by the end of 2018."],
            ["However, it was unable to fulfil its promise, and rolled out the update this month, after much delay."], 
            ["OnePlus is evidently looking to stay away from over-promising this time around."]]

# %%
token_senteces = []
for i in senteces:
    token_senteces.append(nltk.word_tokenize((" ".join(i).lower())))

# %%
print(token_senteces)
# Out:
# [['oneplus', 'has', 'confirmed', 'that', 'the', 'oneplus', '5', 'and', 'oneplus', '5t', 'will', 'get', 'the', 'android', 'q', 'update', '.'], ['the', 'company', 'has', 'announced', 'this', 'on', 'its', 'forums', ',', 'but', 'has', 'cautioned', 'that', 'users', 'should', 'not', 'expect', 'a', 'launch', 'timeline', '.'], ['the', 'company', 'faced', 'a', 'lot', 'of', 'flak', 'for', 'committing', 'to', 'the', 'android', 'pie', 'rollout', 'for', 'the', 'oneplus', '3', 'and', 'oneplus', '3t', 'by', 'the', 'end', 'of', '2018', '.'], ['however', ',', 'it', 'was', 'unable', 'to', 'fulfil', 'its', 'promise', ',', 'and', 'rolled', 'out', 'the', 'update', 'this', 'month', ',', 'after', 'much', 'delay', '.'], ['oneplus', 'is', 'evidently', 'looking', 'to', 'stay', 'away', 'from', 'over-promising', 'this', 'time', 'around', '.']]

# %%
model = Word2Vec(token_senteces, min_count=2, size=50)

# %%
print(model), type(model)
# Out:
# Word2Vec(vocab=16, size=50, alpha=0.025)
# (None, gensim.models.word2vec.Word2Vec)

# %%
list(model.wv.vocab)
# Out:
# ['oneplus',
#  'has',
#  'that',
#  'the',
#  'and',
#  'android',
#  'update',
#  '.',
#  'company',
#  'this',
#  'its',
#  ',',
#  'a',
#  'of',
#  'for',
#  'to']

# %%
model["oneplus"].shape
# Out:
# /home/kumarmai/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# (50,)

# %%
model["oneplus"]
# Out:
# /home/kumarmai/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.00110923, -0.00663776, -0.00982957, -0.00895332,  0.00359336,
#        -0.0014347 ,  0.00405664, -0.0033393 ,  0.00775625, -0.0089685 ,
#        -0.00535061,  0.00164576,  0.00191293, -0.00216971, -0.0079822 ,
#         0.00850877, -0.0013988 , -0.00939115,  0.00063336, -0.00948247,
#        -0.00382636,  0.00057933,  0.00696991,  0.00423948, -0.00715457,
#        -0.00062409, -0.00128214,  0.00072098,  0.00953256,  0.0054769 ,
#         0.00618673,  0.00497267,  0.0009296 , -0.0058856 , -0.0089881 ,
#        -0.00084889,  0.00606663,  0.00851164, -0.00933953,  0.00337116,
#         0.00489142, -0.00551143, -0.00508058,  0.00109866,  0.00412591,
#        -0.00250859,  0.00592661, -0.00418482, -0.00926363,  0.00429692],
# ...

# %%
model.save("../OnePlus_word2Vec.bin")

# %%
model = Word2Vec.load("../OnePlus_word2Vec.bin")

# %%
model[model.wv.vocab].shape
# Out:
# /home/kumarmai/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# (16, 50)

# %%
X = model[model.wv.vocab]
# Out:
# /home/kumarmai/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca_result = pca.fit_transform(X)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.13398887, 0.11862563], dtype=float32)

# %%
pca_result.shape
# Out:
# (16, 2)

# %%
plt.scatter(pca_result[:, 0], pca_result[:, 1])
for index, word in enumerate(model.wv.vocab):
    plt.annotate(word, xy= (pca_result[index, 0], pca_result[index, 1]))
plt.show()

# %%
# !pwd
# Out:
# /mnt/c/Users/kumarmai/Downloads/Jupyter files

# %% [markdown]
# ###  Google Word2Vec

# %%
#Word2Vec can be downloaded from - https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
word2Vec_path = "/mnt/c/Users/kumarmai/Downloads/GoogleNews-vectors-negative300.bin.gz"

# %%
# the Word2Vec.load_word2vec_format is depericated and cant be used any more 
# So use gensim.model.keyedvector.KeyedVectors.load_word2vec_format

# %%
# %%time
google_model = gensim.models.keyedvectors.KeyedVectors.load_word2vec_format(word2Vec_path, binary=True)
# Out:
# CPU times: user 6min 28s, sys: 45.3 s, total: 7min 13s
# Wall time: 8min 29s

# %%
len(list(google_model.wv.vocab))
# Out:
# /home/kumarmai/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# 3000000

# %%
google_model.most_similar("father")
# Out:
# [('son', 0.8933086395263672),
#  ('uncle', 0.8542662262916565),
#  ('brother', 0.8240806460380554),
#  ('grandfather', 0.8048632144927979),
#  ('dad', 0.8040657043457031),
#  ('mother', 0.7901482582092285),
#  ('nephew', 0.788079023361206),
#  ('stepfather', 0.7810977697372437),
#  ('eldest_son', 0.7770525217056274),
#  ('grandson', 0.7620671987533569)]

# %%
google_model.most_similar("good")
# Out:
# [('great', 0.7291510105133057),
#  ('bad', 0.7190051078796387),
#  ('terrific', 0.6889115571975708),
#  ('decent', 0.6837348937988281),
#  ('nice', 0.6836092472076416),
#  ('excellent', 0.644292950630188),
#  ('fantastic', 0.6407778263092041),
#  ('better', 0.6120728254318237),
#  ('solid', 0.5806034803390503),
#  ('lousy', 0.5764201879501343)]

# %%
google_model.most_similar("facebook")
# Out:
# [('Facebook', 0.7563532590866089),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988551616668701),
#  ('myspace', 0.6941817402839661),
#  ('Twitter', 0.6642444729804993),
#  ('twitter_facebook', 0.6572229862213135),
#  ('Facebook.com', 0.6529868245124817),
#  ('myspace_facebook', 0.6370644569396973),
#  ('facebook_twitter', 0.6367617845535278),
#  ('linkedin', 0.6356592774391174)]

# %%
google_model.most_similar("Google")
# Out:
# [('Google_Nasdaq_GOOG', 0.7819363474845886),
#  ('Google_GOOG', 0.7756521105766296),
#  ('Google_NASDAQ_GOOG', 0.7557772994041443),
#  ('Google_NSDQ_GOOG', 0.7538512945175171),
#  ('Yahoo', 0.7491980195045471),
#  ('GoogleGoogle', 0.7281472086906433),
#  ('search_engine', 0.7255110740661621),
#  ('Google_nasdaq_GOOG', 0.7014852166175842),
#  ('Baidu', 0.6993465423583984),
#  ('NASDAQ_GOOG', 0.6812566518783569)]

# %%
google_model["flower"].shape
# Out:
# (300,)

# %%
google_model.most_similar(positive=["women", "king"], negative=["queen"])
# Out:
# [('men', 0.6595240831375122),
#  ('Men', 0.47685354948043823),
#  ('Women', 0.45662593841552734),
#  ('widows_divorcees', 0.44920507073402405),
#  ('husbands', 0.4306999146938324),
#  ('fathers', 0.42320168018341064),
#  ('womens', 0.41944700479507446),
#  ('MSMs', 0.4129616320133209),
#  ('males', 0.410765677690506),
#  ('wear_burkas', 0.4105762541294098)]

# %%
king = google_model["king"]
queen = google_model["queen"]
men = google_model["men"]
women = google_model["women"]

# %%
import numpy as np

# %%
np.mean(king - women)
# Out:
# 0.013054823

# %%
np.mean(queen - men)
# Out:
# 0.015777085

# %%
len(google_model.index2word)
# Out:
# 3000000

# %%
import pprint

# %%
print(senteces)
# Out:
# [['OnePlus has confirmed that the OnePlus 5 and OnePlus 5T will get the Android Q update.'], ['The company has announced this on its forums, but has cautioned that users should not expect a launch timeline.'], ['The company faced a lot of flak for committing to the Android Pie rollout for the OnePlus 3 and OnePlus 3T by the end of 2018.'], ['However, it was unable to fulfil its promise, and rolled out the update this month, after much delay.'], ['OnePlus is evidently looking to stay away from over-promising this time around.']]

# %%
word2vec_dict = {}
for sent in senteces:
    for word in sent[0].split(" "):
#         print(word)
        if word not in word2vec_dict:
            try:
                word2vec_dict[word] = google_model[word]
            except:
                word2vec_dict[word] = None

# %%
word2vec_dict
# Out:
# {'OnePlus': None,
#  'has': array([-4.49218750e-02, -3.03955078e-02,  2.34985352e-03, -6.59179688e-03,
#          8.78906250e-02,  3.29589844e-02, -9.42382812e-02, -2.41210938e-01,
#         -5.73730469e-02,  2.26562500e-01, -1.91406250e-01, -1.68945312e-01,
#          8.20312500e-02, -6.39648438e-02,  1.46484375e-01,  1.00585938e-01,
#          1.36718750e-01,  6.68945312e-02, -1.74804688e-01,  1.11083984e-02,
#         -3.51562500e-02,  2.65625000e-01,  1.55273438e-01, -1.96289062e-01,
#         -5.12695312e-02, -6.17675781e-02, -8.39843750e-02,  1.57470703e-02,
#          4.39453125e-02,  4.34570312e-02,  1.48437500e-01,  1.31835938e-01,
#         -9.76562500e-02,  2.18750000e-01,  3.02734375e-01, -7.08007812e-02,
#         -8.88671875e-02, -1.79687500e-01,  3.15856934e-03, -3.01513672e-02,
#          1.29882812e-01,  1.61132812e-01, -1.43554688e-01,  7.82012939e-04,
#          4.24804688e-02,  6.98852539e-03, -3.29589844e-02,  7.37304688e-02,
# ...

# %% [markdown]
# ### PCA on Google Word2Vec

# %% [markdown]
# <img src="https://ahmedbesbes.com/images/w2v_1.jpg"/>

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
list_of_words = ["brother", "uncle", "nephew", "man", "woman", "sir", "king", "emperor", "duke", 
                "queen", "earl", "sister", "aunt", "niece", "empress", "duchess", "madam"]

# %%
list_of_words_vector = [google_model[i] for i in list_of_words]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-3b02dfd38741> in <module>
# ----> 1 list_of_words_vector = [google_model[i] for i in list_of_words]
#
# <ipython-input-29-3b02dfd38741> in <listcomp>(.0)
# ----> 1 list_of_words_vector = [google_model[i] for i in list_of_words]
#
# NameError: name 'google_model' is not defined

# %%
list_of_words_vector = np.array(list_of_words_vector)

# %%
pca_result = pca.fit_transform(list_of_words_vector)

# %%
plt.subplots(figsize=(12,7))
plt.scatter(pca_result[:, 0], pca_result[:, 1])

for index, word in enumerate(list_of_words):
    plt.annotate(word, xy= (pca_result[index, 0], pca_result[index, 1]))
plt.show()

# %% [markdown]
# #### Plotting Google Word2Vec

# %%
# !pip3 install bokeh
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 8.6 MB 1.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.1 MB 4.6 MB/s eta 0:00:01
# ...
#   Created wheel for bokeh: filename=bokeh-2.0.2-py3-none-any.whl size=9072535 sha256=2ad87b4c833da8b5c44deafbb9c7d749210113f303c25d8e9a3ab53ddc899564
#   Stored in directory: /home/kumarmai/.cache/pip/wheels/b0/68/c1/6b9042ddb66b14320f3a38df7bdcb38c4b411be9daae9df900
# Successfully built bokeh
# ...

# %%
import bokeh.plotting as bp
from bokeh.models import HoverTool,BoxSelectTool
from bokeh.plotting import figure, show, output_notebook

# defining the chart
output_notebook()
plot_tfidf = bp.figure(plot_width=700, plot_height=600, title="A map of 10000 word vectors",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1018">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-a5f85d47f5ac> in <module>
#       7 plot_tfidf = bp.figure(plot_width=700, plot_height=600, title="A map of 10000 word vectors",
#       8     tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
# ----> 9     x_axis_type=None, y_axis_type=None, min_border=1)
#
# ~/.local/lib/python3.6/site-packages/bokeh/plotting/figure.py in figure(**kwargs)
#    1362
#    1363 def figure(**kwargs):
# -> 1364     return Figure(**kwargs)
#    1365 figure.__doc__ = Figure.__doc__
#    1366
#
# ~/.local/lib/python3.6/site-packages/bokeh/plotting/figure.py in __init__(self, *arg, **kw)
# ...

# %%
word_vectors = [google_model[w] for w in list(google_model.wv.vocab)[:500]]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.

# %%
len(word_vectors)
# Out:
# 500

# %%
from sklearn.manifold import TSNE
tsne_model = TSNE(n_components=2, verbose=1, random_state=0)
tsne_w2v = tsne_model.fit_transform(word_vectors)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 500 samples in 0.014s...
# [t-SNE] Computed neighbors for 500 samples in 0.434s...
# [t-SNE] Computed conditional probabilities for sample 500 / 500
# [t-SNE] Mean sigma: 0.800760
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 102.113144
# [t-SNE] KL divergence after 1000 iterations: 1.348062

# %%
# putting everything in a dataframe
tsne_df = pd.DataFrame(tsne_w2v, columns=['x', 'y'])
tsne_df['words'] = list(google_model.wv.vocab)[:500]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# plotting. the corresponding word appears when you hover on the data point.
plot_tfidf.scatter(x='x', y='y', source=tsne_df)
hover = plot_tfidf.select(dict(type=HoverTool))
hover.tooltips={"word": "@words"}
show(plot_tfidf)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a861174a-d30e-411c-8a5c-d0f456b7df1a"></div>
# </div>

# %%
# Download Glove and read it thrrough KeyedVector
from gensim.scripts.glove2word2vec import glove2word2vec
